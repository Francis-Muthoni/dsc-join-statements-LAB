# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge of `JOIN` statements, using various types of joins and various methods for specifying the links between them.
#
# ## Objectives
#
# You will be able to:
#
# * Write SQL queries that make use of various types of joins
# * Compare and contrast the various types of joins
# * Discuss how primary and foreign keys are used in SQL
# * Decide and perform whichever type of join is best for retrieving desired data

# %% [markdown]
# ## CRM ERD
#
# In this lab, you'll use the same customer relationship management (CRM) database that you saw from the previous lesson.
# <img src='https://curriculum-content.s3.amazonaws.com/data-science/images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database `'data.sqlite'`.

# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database
conn = sqlite3.connect('data.sqlite')
cur = conn.cursor()

# Check if the connection is established
if conn:
    print("Connection established successfully.")

# Query to get the list of tables
cur.execute("SELECT name FROM sqlite_master WHERE type='table';")

# Fetch all table names
tables = cur.fetchall()

# Check if there are any tables and print the table names
if tables:
    print("Tables in the database:")
    for table in tables:
        print(table[0])
else:
    print("No tables found in the database.")
# Out:
# Connection established successfully.
# Tables in the database:
# productlines
# offices
# customers
# employees
# orderdetails
# orders
# payments
# products

# %% [markdown]
# ## Select the names of all employees in Boston
#
# Hint: join the employees and offices tables. Select the first and last name.

# %%
# Your code here
#Execute the query
query = """
SELECT employees.firstName, employees.lastName
FROM employees
INNER JOIN offices
ON employees.officeCode = offices.officeCode;
"""

# %%
pd.read_sql(query, conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\USER\Documents\anaconda\envs\learn-env\Lib\site-packages\pandas\io\sql.py:2672, in SQLiteDatabase.execute(self, sql, params)
#    2671 try:
# -> 2672     cur.execute(sql, *args)
#    2673     return cur
#
# OperationalError: no such table: employees
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pd.read_sql(query, conn)
#
# File c:\Users\USER\Documents\anaconda\envs\learn-env\Lib\site-packages\pandas\io\sql.py:706, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     704 with pandasSQL_builder(con) as pandas_sql:
#     705     if isinstance(pandas_sql, SQLiteDatabase):
# --> 706         return pandas_sql.read_query(
#     707             sql,
#     708             index_col=index_col,
#     709             params=params,
#     710             coerce_float=coerce_float,
#     711             parse_dates=parse_dates,
#     712             chunksize=chunksize,
#     713             dtype_backend=dtype_backend,
#     714             dtype=dtype,
#     715         )
#     717     try:
#     718         _is_table_name = pandas_sql.has_table(sql)
#
# File c:\Users\USER\Documents\anaconda\envs\learn-env\Lib\site-packages\pandas\io\sql.py:2736, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2725 def read_query(
#    2726     self,
#    2727     sql,
#    (...)
#    2734     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2735 ) -> DataFrame | Iterator[DataFrame]:
# -> 2736     cursor = self.execute(sql, params)
#    2737     columns = [col_desc[0] for col_desc in cursor.description]
#    2739     if chunksize is not None:
#
# File c:\Users\USER\Documents\anaconda\envs\learn-env\Lib\site-packages\pandas\io\sql.py:2684, in SQLiteDatabase.execute(self, sql, params)
#    2681     raise ex from inner_exc
#    2683 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2684 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT employees.firstName, employees.lastName
# FROM employees
# INNER JOIN offices
# ON employees.officeCode = offices.officeCode;
# ': no such table: employees

# %% [markdown]
# ## Are there any offices that have zero employees?
# Hint: Combine the employees and offices tables and use a group by. Select the office code, city, and number of employees.

# %%
# Your code here

# %% [markdown]
# ## Write 3 questions of your own and answer them

# %%
# Answers will vary

# Example question: 
"""
How many customers are there per office?
"""

# %%
"""
Question 1
"""

# Your code here

# %%
"""
Question 2
"""

# Your code here

# %%
"""
Question 3
"""

# Your code here

# %% [markdown]
# ## Level Up 1: Display the names of every individual product that each employee has sold
#
# Hint: You will need to use multiple `JOIN` clauses to connect all the way from employee names to product names.

# %%
# Your code here

# %% [markdown]
# ## Level Up 2: Display the number of products each employee has sold
#
# Alphabetize the results by employee last name.
#
# Hint: Use the `quantityOrdered` column from `orderDetails`. Also, think about how to group the data when some employees might have the same first or last name.

# %%
# Your code here

# %% [markdown]
# ## Level Up 3: Display the names employees who have sold more than 200 different products
#
# Hint: this is different from the previous question because the quantity sold doesn't matter, only the number of different products

# %%
# Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You practiced using join statements and leveraged your foreign keys knowledge!
